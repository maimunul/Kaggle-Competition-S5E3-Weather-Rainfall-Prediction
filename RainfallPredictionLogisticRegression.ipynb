# %% [markdown]
# <a href="https://www.kaggle.com/code/maimunulkjisan/rainfall-prediction-playground-series-s5e3?scriptVersionId=226767982" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## 🧠 Welcome to the *Exploring Rainfall Prediction* Notebook!
#
# > Welcome to our Kaggle notebook for the **Exploring Rainfall Prediction** competition! In this notebook, we aim to explore, analyze, and model data from a **Kaggle Competition** to identify factors associated with Rainfall Prediction. This competition is part of Kaggle's **2025 Playground Series 5 Episode 3**, designed to challenge and enhance our machine learning skills. Let’s dive in and uncover insights from the data!
#
# ---
#
#
#
# <figure>
#   <center>
#     <img src='https://c4.wallpaperflare.com/wallpaper/231/640/853/walking-in-rain-painting-wallpaper-preview.jpg'
#          height="50px" width="400px" />
#   </center>
# </figure>
#
#
# # 🏆 Kaggle Competition S5E3: Weather Rainfall Prediction | Logistic Regression 🌦️
#
# ## 📋 Table of Contents
#
#
#
# ### 1. [🎯 Introduction](#🎯-introduction)
#    - Overview of the competition and goals.
#
# ### 2. [📦 Libraries and Setup](#📦-libraries-and-setup)
#    - Required libraries and environment setup.
#
# ### 3. [🛠️ Data Loading](#🛠️-data-loading-and-initial-analysis)
#    - Data loading, cleaning, and initial exploration.
#
# ### 4. [🔧 Feature Engineering](#🔧-feature-engineering)
#    - Extracting meaningful features for prediction.
#
# ### 5. [🚂 Model Training](#🚂-model-training-and-evaluation)
#    - Building and training the machine learning models.
#
# ### 6. [🎯 Hyperparameter Tuning](#🎯-hyperparameter-tuning-with-optuna)
#    - Optimizing the model using Optuna.
#
# ### 7. [📤 Predictions](#📤-saving-predictions)
#    - Generating and saving the predictions.
#
# ### 8. [🎉 Conclusion](#🎉-conclusions-and-next-steps)
#    - Final thoughts and next steps.
#
# ---
#
#
#
# ## 🎯 Dataset Description for Weather Prediction | Kaggle Competition Data🎯
#
# | Column Name   | Description                                                                 | Data Type |
# |----------------|-----------------------------------------------------------------------------|-----------|
# | day            | The day number representing the time of the weather data.                    | Integer   |
# | pressure       | The atmospheric pressure at the given time, measured in hPa.                | Float     |
# | maxtemp        | The maximum temperature for the day in degrees Celsius.                     | Float     |
# | temparature    | The average temperature for the day in degrees Celsius.                     | Float     |
# | mintemp        | The minimum temperature for the day in degrees Celsius.                     | Float     |
# | dewpoint       | The dewpoint temperature in degrees Celsius, indicating moisture in the air.| Float     |
# | humidity       | The humidity level in percentage, indicating the amount of moisture in the air.| Float     |
# | cloud          | The percentage of cloud cover for the day.                                  | Float     |
# | sunshine       | The number of hours of sunshine during the day.                             | Float     |
# | winddirection  | The wind direction, measured in degrees from North (0° to 360°).            | Float     |
# | windspeed      | The wind speed in km/h.                                                     | Float     |
# | rainfall       | The rainfall amount in millimeters for the day (binary classification: 1 for rain, 0 for no rain).| Integer   |
#
# ---
#
# **Competition Goal** 🏁
# Predict rainfall occurrence using meteorological data with machine learning.
#
# **Key Challenge** 🔍
# Class imbalance + temporal patterns + hyperparameter in weather data requiring special handling.
#
# **Evaluation Metric** 📏
# **ROC-AUC Score** - Measures model's ability to distinguish between rainy and non-rainy days.
#
# **Our Arsenal** 💡
# - Advanced feature engineering
# - Time-aware cross-validation
# - Hyperparameter optimization with Optuna
# - Logistic Regression as baseline
#
# ---
#
# ## 🧩 Full Project Architecture
#
#
# ```mermaid
# graph TD
#     A[Raw Data] --> B[Data Preparation]
#     B --> C[Feature Engineering Galaxy]
#     C --> D[Preprocessing Pipeline]
#     D --> E[Model Training]
#     E --> F[Evaluation]
#     F --> G[Kaggle Submission]
#
#     %% Data Preparation
#     subgraph B[Data Preparation]
#         B1[🔄 Merge Train/Test/Extra]
#         B2[📅 DateTime Conversion]
#         B3[🧹 Handle Missing Values]
#         B4[⚖️ Class Balance Check]
#     end
#
#     %% Feature Engineering
#     subgraph C[Feature Engineering]
#         C1[⏳ Temporal Features]
#         C2[🌡️ Thermodynamics]
#         C3[📈 Rolling Statistics]
#         C4[🧩 Polynomial Interactions]
#         C5[🌪️ Wind Vector Decomposition]
#     end
#
#     %% Preprocessing
#     subgraph D[Preprocessing Pipeline]
#         D1[🔧 Median Imputation]
#         D2[⚖️ Standard Scaling]
#         D3[🎯 Feature Selection]
#     end
#
#     %% Model Training
#     subgraph E[Model Training]
#         E1[🎛️ Optuna Tuning]
#         E2[🤖 Logistic Regression]
#         E3[⏳ TimeSeriesSplit]
#         E4[⚖️ Class Weight Handling]
#     end
#
#     %% Evaluation
#     subgraph F[Evaluation]
#         F1[📊 ROC-AUC Curve]
#         F2[🎯 Optimal Threshold]
#         F3[🤔 Confusion Matrix]
#     end
#
#     %% Submission
#     subgraph G[Kaggle Submission]
#         G1[🔮 Probability Calibration]
#         G2[📤 CSV Export]
#     end
#
#     %% Styling
#     style A fill:#20B2AA,stroke:#333,stroke-width:2px
#     style B fill:#87CEEB,stroke:#333,stroke-width:2px
#     style C fill:#98FB98,stroke:#333,stroke-width:2px
#     style D fill:#FFB6C1,stroke:#333,stroke-width:2px
#     style E fill:#DDA0DD,stroke:#333,stroke-width:2px
#     style F fill:#FFA07A,stroke:#333,stroke-width:2px
#     style G fill:#20B2AA,stroke:#333,stroke-width:2px

# %% [markdown]
# 📦 Libraries and Setup
# =====================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from IPython.display import display
import optuna
from optuna.samplers import TPESampler
from optuna.visualization import plot_optimization_history, plot_parallel_coordinate, plot_slice
from optuna.visualization import plot_contour, plot_param_importances
from plotly.subplots import make_subplots
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import PolynomialFeatures
import warnings
from tabulate import tabulate
import plotly.graph_objects as go
warnings.filterwarnings('ignore')

print("✅ Packages loaded!")
# Out:
# ✅ Packages loaded!

# %% [markdown]
# ## 🎓 **Theory Time!** 🧠
# > Before diving into the implementation, let's set up our essential packages! 🚀
#
# ### 📦 **Importing Essential Libraries**
#
# We import the necessary packages for:
#
# - 🏗 **Data Manipulation** → `pandas`, `numpy`
# - 📊 **Visualization** → `matplotlib`, `seaborn`
# - 🤖 **Machine Learning** → `scikit-learn`
# - 🎯 **Hyperparameter Tuning** → `optuna`
#
# 💡 **Why Optuna?**
# Optuna’s `TPESampler` efficiently explores the hyperparameter space, helping us optimize model performance with minimal computational cost! 🔥
#
# ---

# %% [markdown]
# # **🛠️ Data Loading**

# %%
def load_data():
    train = pd.read_csv("/kaggle/input/playground-series-s5e3/train.csv", index_col='id')
    test = pd.read_csv("/kaggle/input/playground-series-s5e3/test.csv", index_col='id')
    extra = pd.read_csv("/kaggle/input/rainfall-prediction-using-machine-learning/Rainfall.csv")
    return train, test, extra

train_df, test_df, extra_df = load_data()

print("📊 Data Shapes:")
display(f"Train: {train_df.shape}", f"Test: {test_df.shape}", f"Extra: {extra_df.shape}")
print("\n🔍 First 3 rows of training data:")
display(train_df.head(3))
# Out:
# 📊 Data Shapes:
# 'Train: (2190, 12)'
# 'Test: (730, 11)'
# 'Extra: (366, 12)'
# 🔍 First 3 rows of training data:
#     day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# id
# 0     1    1017.4     21.2         20.6     19.9      19.4      87.0   88.0
# 1     2    1019.5     16.2         16.9     15.8      15.4      95.0   91.0
# 2     3    1024.1     19.4         16.1     14.6       9.3      75.0   47.0
#
#     sunshine  winddirection  windspeed  rainfall
# id
# 0        1.1           60.0       17.2         1
# 1        0.0           50.0       21.9         1
# 2        8.3           70.0       18.1         1

# %% [markdown]
# ## **🔑Key Operations**
#
#
# ### 📥 **Data Preparation & Integration**
#
# - 📂 **Loading Datasets** → Competition data + external rainfall dataset 🌧
# - 🕰 **Time Series Handling** → Special preprocessing for date-based insights 📆
# - 🔗 **Data Merging** → Combining sources while preserving data lineage 🏗
#
# 📌 **Goal:** Ensure seamless integration while maintaining data integrity! 🚀
#
#
# ---
#
# ### 📊 **Data Shapes**
# | Dataset  | Shape |
# |----------|--------|
# | 🏋 **Train** | `(2190, 12)` |
# | 🧪 **Test**  | `(730, 11)`  |
# | 🌧 **Extra** | `(366, 12)`  |
# | 🔄 **Total (Train + Extra)** | `(2556, 12)` |
#
# ---

# %% [markdown]
# # 🔧 **Feature Engineering**
#
#
# ## 🌤️ **Meteorology 101**
# We engineered **35+ features**, covering various aspects of weather patterns and temporal dynamics.
#
# ### **Key Features Added** 🔑
# - 📅 **Temporal Features** → Day-of-year harmonics (**sin/cos**)
# - 🌡 **Thermodynamic Features** → Dewpoint depression, absolute humidity
# - 📊 **Rolling Statistics** → 7-day pressure trends
# - 🔗 **Interaction Terms** → Temperature-humidity interactions
# - 🔢 **Polynomial Features** → 2nd-degree interactions
#
# ---

# %%
# ======================
# Feature Engineering
# ======================
def feature_engineering(df):
    df['date'] = pd.to_datetime(df['date']) if 'date' in df.columns else pd.date_range(start='2015-01-01', periods=len(df), freq='D')
    df['day_of_year'] = df['date'].dt.dayofyear
    df['month'] = df['date'].dt.month
    df['is_weekend'] = (df['date'].dt.weekday >= 5).astype(int)
    
    # ------------------- Day & Seasonal Features -------------------
    df['day_sin'] = np.sin(2 * np.pi * df['day_of_year'] / 365)
    df['day_cos'] = np.cos(2 * np.pi * df['day_of_year'] / 365)

    # ------------------- Pressure Features -------------------
    df['pressure_rolling_mean'] = df['pressure'].rolling(window=7, min_periods=1).mean()
    df['pressure_rolling_std'] = df['pressure'].rolling(window=7, min_periods=1).std()
    df['pressure_diff'] = df['pressure'].diff()

    # ------------------- Temperature Features -------------------
    df['temp_range'] = df['maxtemp'] - df['mintemp']
    df['temp_ewm'] = df['temparature'].ewm(span=10, adjust=False).mean()
    df['temp_change'] = df['temparature'].diff()
    df['temp_humidity_interaction'] = df['temparature'] + (0.2 * df['humidity'])

    # ------------------- Dewpoint & Humidity Features -------------------
    df['dewpoint_depression'] = df['temparature'] - df['dewpoint']
    df['rh_approx'] = 100 - (5 * df['dewpoint_depression'])

    # Saturation Vapor Pressure (SVP) - Tetens' Equation
    df['svp'] = 6.1078 * np.exp((17.27 * df['temparature']) / (df['temparature'] + 237.3))

    # Absolute Humidity (AH) in g/m³
    df['abs_humidity'] = (6.112 * np.exp((17.67 * df['temparature']) / (df['temparature'] + 243.5)) * df['humidity'] * 2.1674) / (273.15 + df['temparature'])

    # ------------------- Cloud & Sunshine Features -------------------
    df['cloud_category'] = pd.cut(df['cloud'], bins=[0, 20, 50, 80, 100], labels=[0, 1, 2, 3])
    df['cloud_category'] = df['cloud_category'].astype(float)
    df['sky_opacity'] = df['cloud'] / 100
    df['sunshine_pct'] = df['sunshine'] / 24
    df['cloud_sun_ratio'] = df['cloud'] / (df['sunshine'] + 1e-6)
    df['interaction'] = df['cloud'] + df['sunshine'] + df['humidity']

    # ------------------- Wind Features -------------------
    df['winddir_sin'] = np.sin(np.radians(df['winddirection']))
    df['winddir_cos'] = np.cos(np.radians(df['winddirection']))

    # ------------------- Polynomial Features -------------------
    poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
    poly_features = ['temparature', 'humidity', 'pressure', 'windspeed', 'cloud']
    df_poly = pd.DataFrame(poly.fit_transform(df[poly_features]), columns=poly.get_feature_names_out(poly_features))
    df_poly = df_poly.add_prefix("poly_")
    df = df.join(df_poly)

    return df


print("✨ 35+ New Features Created!")
# Out:
# ✨ 35+ New Features Created!

# %% [markdown]
# ```mermaid
# graph TD
#     subgraph "Feature Engineering Galaxy (FeatureTools Inspired)"
#         C1[Temporal Features]
#         C2[Thermodynamic Features]
#         C3[Rolling Statistics]
#         C4[Polynomial Interactions]
#         C5[Wind Vector Decomposition]
#         C6[Cloud Categories]
#         C7[Advanced Humidity Metrics]
#         C8[Satellite-like Features]
#     end

# %% [markdown]
# ## 🧪 **Science Behind the Features**
# We leverage **meteorological formulas** such as:
# - 🌡 **Tetens' equation** → For calculating **saturation vapor pressure**
# - 💨 **Wind Component Analysis** → Decomposing wind vectors into meaningful features
#
# 📌 **Why?**
# These engineered features enhance model performance by capturing intricate relationships between weather patterns and temporal effects. 🚀
#
# ---

# %% [markdown]
# 🔄 Preprocessing Pipeline
# ===============================
#
#
# **Pipeline** 🤖
# ```mermaid
# graph LR
# A[Raw Data] --> B{Preprocessor}
# B --> C[Imputation]
# B --> D[Scaling]
# B --> E[Feature Engineering]
# E --> F[Logistic Regression]

# %%
# ======================
# Preprocessing Pipeline
# ======================
def create_pipeline(numeric_features):
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features)
        ])
    
    return preprocessor

# %% [markdown]
# ## ⚖️ **Why Scale?**
#
# ### 🚶‍♂️ **Logistic Regression is Distance-Sensitive**
# Logistic Regression depends on the **distance** between data points. Without scaling, features with larger magnitudes dominate, leading to **bias** in model performance.
#
# ---
#
# ### 📏 **StandardScaler (μ=0, σ=1)**
# Scaling the data ensures each feature contributes equally by **normalizing** them to have a **mean (μ)** of 0 and a **standard deviation (σ)** of 1. This prevents any feature from dominating the learning process.
#
# ---
#
# ### 🧳 **Median Imputation**
# Handling missing values is critical! **Median Imputation** is used to fill missing data, which is **robust** to outliers and ensures the dataset remains consistent.
#
# ---
#
# **Why it matters?**
# Scaling the data and handling missing values properly results in **improved model performance** and **better generalization**! 🚀

# %% [markdown]
# 🎯 Hyperparameter Tuning with Optuna
# ===================================
#
# | **Parameter**             | **Type**        | **Values/Range**                              | **Description**                                                              |
# |---------------------------|-----------------|-----------------------------------------------|------------------------------------------------------------------------------|
# | **1. Solver & Penalty**    | 🛠️ **Combinations**  | `('newton-cg', 'l2')`, `('lbfgs', 'l2')`, ...   | Defines the solver and regularization method used for optimization.         |
# | **2. C (Regularization Strength)** | ⚖️ **Float**  | **1e-5 to 100.0** (log scale)                 | Controls regularization; higher C = less regularization.                    |
# | **3. Solver**              | 🔧 **Categorical**   | `'newton-cg'`, `'lbfgs'`, `'liblinear'`, ...   | Determines the algorithm used for optimization.                              |
# | **4. Penalty**             | 💡 **Categorical**   | `'l1'`, `'l2'`, `'elasticnet'`, `'none'`      | The regularization term applied to the model.                               |
# | **5. Max Iterations**     | ⏳ **Integer**       | **100 to 5000**                              | Specifies the maximum number of iterations for optimization.                |
# | **6. Class Weight**       | ⚖️ **Categorical**   | `None`, `'balanced'`                          | Adjusts class weights for imbalanced datasets.                              |
# | **7. Tolerance (tol)**    | 📏 **Float**        | **1e-6 to 1e-2** (log scale)                 | Controls the stopping criterion for optimization.                           |
# | **8. Fit Intercept**      | 🔲 **Categorical**   | `True`, `False`                               | Indicates if the intercept is included in the model.                        |
# | **9. Warm Start**         | 🔄 **Categorical**   | `True`, `False`                               | Reuses previous solution to speed up convergence.                           |
# | **10. Intercept Scaling** | 📊 **Float** (for `liblinear`) | **0.1 to 10.0**                             | Scaling factor for the intercept term when using the `liblinear` solver.   |
# | **11. L1 Ratio**          | 🔄 **Float** (for `elasticnet`) | **0.0 to 1.0**                              | Defines the mix ratio between L1 and L2 penalties in elasticnet.            |

# %%
# ======================
# Optuna Objective Function
# ======================
def objective(trial, X, y, preprocessor, model_name):
    solver_penalty_combinations = [
        ('newton-cg', 'l2'),
        ('lbfgs', 'l2'),
        ('liblinear', 'l1'),
        ('liblinear', 'l2'),
        ('sag', 'l2'),
        ('saga', 'elasticnet'),
        ('saga', 'l1'),
        ('saga', 'l2'),
        ('saga', 'none')
    ]
    
    solver, penalty = trial.suggest_categorical('solver_penalty', solver_penalty_combinations)
    
    params = {
        'C': trial.suggest_float('C', 1e-5, 100.0, log=True),
        'solver': solver,
        'penalty': penalty,
        'max_iter': trial.suggest_int('max_iter', 100, 5000),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced']),
        'tol': trial.suggest_float('tol', 1e-6, 1e-2, log=True),
        'fit_intercept': trial.suggest_categorical('fit_intercept', [True, False]),
        'warm_start': trial.suggest_categorical('warm_start', [True, False]),
        'intercept_scaling': trial.suggest_float('intercept_scaling', 0.1, 10.0) if solver == 'liblinear' else 1.0,
        'l1_ratio': trial.suggest_float('l1_ratio', 0.0, 1.0) if penalty == 'elasticnet' else None
    }
    
    # Handle custom class weights
    # if params['class_weight'] == 'custom':
    #     class_weights = trial.suggest_float('class_weight_ratio', 0.1, 10.0)
    #     params['class_weight'] = {0: 1.0, 1: class_weights}
    #     # Remove the ratio parameter from the final params
    #     if 'class_weight_ratio' in params:
    #         del params['class_weight_ratio']
    
    # Clean up None values
    params = {k: v for k, v in params.items() if v is not None}
    
    try:
        model = LogisticRegression(**params)
    except ValueError as e:
        return 0.5

    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', model)
    ])
    
    try:
        score = cross_val_score(pipeline, X, y, cv=TimeSeriesSplit(n_splits=5), 
                              scoring='roc_auc', n_jobs=-1).mean()
    except:
        score = 0.5
        
    return score

def tune_hyperparameters(X, y, preprocessor, model_name):
    study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
    study.optimize(lambda trial: objective(trial, X, y, preprocessor, model_name), 
                 n_trials=1000, show_progress_bar=True)
    
    if len(study.trials) == 0:
        raise ValueError(f"No completed trials for {model_name}. Check parameter constraints.")
        
    return study.best_params, study

# %% [markdown]
# ## 🧙‍♂️ **Optuna Magic**
#
# ### 🔮 **TPE Sampler**
# The **TPE (Tree-structured Parzen Estimator) Sampler** intelligently explores the hyperparameter space, ensuring a balance between **exploration** and **exploitation**. This leads to more efficient optimization and faster convergence.
#
# ---
#
# ### **Key Parameters Tuned** 🔑
# - ⚖️ **Regularization Strength (C)** → Controls the trade-off between model complexity and fitting the training data.
# - 🔧 **Solver-Penalty Combinations** → Determines the best solver and penalty method for optimal performance.
# - ⚖️ **Class Weights for Imbalance** → Adjusts weights for imbalanced classes to improve model fairness.
#
# ---
#
# ### 🧠 **Exploration-Exploitation Balance**
# With **1000 trials**, the **TPE sampler** achieves a balance between thorough exploration and efficient exploitation of the search space. This allows us to find the **best hyperparameters** while avoiding overfitting or underfitting.
#
# ---
#
# **Why it works?**
# Optuna's **TPE sampler** accelerates the hyperparameter tuning process, making it smarter and faster! 🚀

# %% [markdown]
# 🧠 Model Training & Evaluation Workflow 🔄
# ===============
#
#
#
# 1. **Model Training** 🏋️‍♂️
#    - Trains the models using the **best-found hyperparameters**.
#    - Uses **time-series cross-validation** to preserve the temporal order of data.
#
# 2. **Evaluation** 📊
#    - Performance is evaluated using the **ROC-AUC score** across all folds.
#    - **Average ROC-AUC** score is calculated to assess model quality.
#
# 3. **Plotting** 📈
#    - **ROC curve** and **Confusion Matrix** are generated to visualize model performance.
#    - Includes plotting with the **optimal threshold** for better decision-making.
#
# 4. **Results** 🏆
#    - Stores and **returns results**, including the best models, parameters, and **Optuna study** for further analysis.

# %%
# ======================
# Model Training & Evaluation
# ======================
def train_and_evaluate(X, y, preprocessor):
    model_configs = {
        'LogisticRegression': (LogisticRegression, {'random_state': 42})
    }
    
    results = {}
    best_models = {}
    best_params = {}
    studies = {}

    for model_name, (model_class, base_params) in model_configs.items():
        print(f"\n{'='*40}")
        print(f"Tuning {model_name}")
        print(f"{'='*40}")
        
        try:
            params, study = tune_hyperparameters(X, y, preprocessor, model_name)
        except ValueError as e:
            print(f"Skipping {model_name}: {str(e)}")
            continue
            
        best_params[model_name] = params
        studies[model_name] = study

        # Process parameters
        if 'solver_penalty' in params:
            solver, penalty = params.pop('solver_penalty')
            params['solver'] = solver
            params['penalty'] = penalty

        # Train final model
        final_model = model_class(**{**base_params, **params})
        pipeline = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('classifier', final_model)
        ])
        
        # Cross-validation
        tscv = TimeSeriesSplit(n_splits=5)
        cv_scores = []
        all_y_true = []
        all_y_pred = []
        
        for fold, (train_idx, val_idx) in enumerate(tscv.split(X)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
            
            try:
                pipeline.fit(X_train, y_train)
                val_preds = pipeline.predict_proba(X_val)[:, 1]
                
                # Store for aggregate metrics
                all_y_true.extend(y_val.tolist())
                all_y_pred.extend(val_preds.tolist())
                cv_scores.append(roc_auc_score(y_val, val_preds))
                print(f"Fold {fold+1}: {cv_scores[-1]:.4f}")
                
            except Exception as e:
                cv_scores.append(0.5)
                print(f"Fold {fold+1}: Failed, using default score 0.5")

        # Aggregate metrics
        mean_score = np.mean(cv_scores)
        results[model_name] = mean_score
        best_models[model_name] = pipeline
        
        # Plot aggregate ROC and CM (only once)
        print("\nAggregate Metrics:")
        roc_fig, optimal_threshold = plot_roc_curve(all_y_true, all_y_pred)
        roc_fig.show()
        
        cm_fig = plot_confusion_matrix(all_y_true, all_y_pred, optimal_threshold)
        cm_fig.show()
        
        print(f"{model_name} Mean ROC-AUC: {mean_score:.4f}")
        print(f"Optimal Threshold: {optimal_threshold:.4f}")
    
    return results, best_models, best_params, studies

# %% [markdown]
# ## Time Series Validation 📅
#
# - **5-Fold Time-Aware Split**:
#   Preserves **temporal order**, ensuring no future data leaks into past predictions.
#
# - **Prevents Lookahead Bias**:
#   Validates model on real-time data while avoiding future knowledge leaks.

# %% [markdown]
# 🚂 Model Insights Visualisation Function  📈
# ==============

# %%
# ======================
# Visualization Function
# ======================

def visualize_optuna_studies(studies):
    for model_name, study in studies.items():
        print(f"\n{'#'*40}")
        print(f"Visualizations for {model_name}")
        print(f"{'#'*40}")
        
        # Get parameters that actually exist in the study
        all_params = study.best_params.keys()
        plot_params = [p for p in ['solver_penalty', 'C', 'tol', 'l1_ratio'] if p in all_params]

        fig = plot_optimization_history(study)
        fig.update_layout(title=f"{model_name} Optimization History", height=500, width=1000)
        fig.show()

        if plot_params:
            fig = plot_parallel_coordinate(study, params=plot_params)
            fig.update_layout(title=f"{model_name} Parameter Relationships", height=600, width=1200)
            fig.show()

            if len(plot_params) >= 2:
                fig = plot_contour(study, params=plot_params[:2])
                fig.update_layout(title=f"{model_name} {plot_params[0]} vs {plot_params[1]}", height=600, width=800)
                fig.show()

        fig = plot_slice(study)
        fig.update_layout(title=f"{model_name} Slice Plot", height=600, width=1200)
        fig.show()

        fig = plot_param_importances(study)
        fig.update_layout(title=f"{model_name} Parameter Importance", height=500, width=1000)
        fig.show()




def plot_logistic_predictions(y_true, y_pred_proba, optimal_threshold):
    # Convert probabilities to binary predictions using the optimal threshold
    y_pred = (y_pred_proba >= optimal_threshold).astype(int)
    
    # Create a scatter plot of predictions vs actual
    plt.figure(figsize=(12, 6))
    
    # Plot correct predictions
    correct_mask = y_true == y_pred
    plt.scatter(
        np.where(correct_mask)[0], y_pred_proba[correct_mask],
        c='green', label='Correct Predictions', alpha=0.6
    )
    
    # Plot incorrect predictions
    incorrect_mask = y_true != y_pred
    plt.scatter(
        np.where(incorrect_mask)[0], y_pred_proba[incorrect_mask],
        c='red', label='Incorrect Predictions', alpha=0.6
    )
    
    # Add optimal threshold line
    plt.axhline(y=optimal_threshold, color='black', linestyle='--', 
                label=f'Optimal Threshold ({optimal_threshold:.2f})')
    
    plt.title('Logistic Regression Predictions on Test Set (Using Optimal Threshold)')
    plt.xlabel('Sample Index')
    plt.ylabel('Predicted Probability')
    plt.legend()
    plt.grid(True)
    plt.show()


def plot_confusion_matrix(y_true, y_pred, threshold=0.5):
    y_pred_labels = (y_pred >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred_labels)
    
    fig = go.Figure(data=go.Heatmap(
        z=cm,
        x=['Predicted 0', 'Predicted 1'],
        y=['Actual 0', 'Actual 1'],
        texttemplate="%{z}",
        colorscale='Blues'))
    
    fig.update_layout(
        title=f'Confusion Matrix (Threshold={threshold:.2f})',
        xaxis_title='Predicted label',
        yaxis_title='True label',
        width=600,
        height=600
    )
    return fig






def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    
    # Find optimal threshold using Youden's J statistic
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]
    
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=fpr, y=tpr,
        mode='lines',
        name=f'ROC Curve (AUC = {roc_auc:.2f})'
    ))
    fig.add_trace(go.Scatter(
        x=[0, 1], y=[0, 1],
        mode='lines',
        line=dict(dash='dash'),
        name='Random'
    ))
    fig.add_trace(go.Scatter(
        x=[fpr[optimal_idx]], y=[tpr[optimal_idx]],
        mode='markers',
        marker=dict(size=10, color='red'),
        name=f'Optimal Threshold ({optimal_threshold:.2f})'
    ))
    fig.update_layout(
        title='ROC Curve',
        xaxis_title='False Positive Rate',
        yaxis_title='True Positive Rate'
    )
    return fig, optimal_threshold

# %% [markdown]
# ## 🎓Theory
# 1. **`visualize_optuna_studies(studies)`** 🧪
#    - Visualizes **Optuna optimization** results.
#    - Includes **parameter relationships**, **optimization history**, and **parameter importance**.
#
# 2. **`plot_logistic_predictions(y_true, y_pred_proba, optimal_threshold)`** 🔍
#    - Plots the **correct** and **incorrect logistic regression predictions**.
#    - Uses the **optimal threshold** to evaluate prediction accuracy.
#
# 3. **`plot_confusion_matrix(y_true, y_pred, threshold=0.5)`** ⚡
#    - Plots a **confusion matrix** for binary predictions.
#    - Threshold can be adjusted to determine the classification boundary.
#
# 4. **`plot_roc_curve(y_true, y_pred_proba)`** 🎯
#    - Plots the **ROC curve** and finds the **optimal threshold**.
#    - Evaluates the model's performance across different thresholds.

# %% [markdown]
# 🚂 Model Pipeline Execution 🚀
# =============
#
# ## Machine Learning Workflow 🔄
#
# 1. **Data Preprocessing** 🧹
#    - Loads **training**, **testing**, and **extra** data.
#    - Cleans **column names**, processes `rainfall` values, and removes **missing data**.
#    - Merges datasets with **source labels** (`main`, `extra`, `test`).
#    - Applies **feature engineering** to the full dataset.
#    - Splits data into **training** and **test sets** based on the **date**.
#
# 2. **Feature Selection** 🔑
#    - Defines a list of **numeric features** for model training.
#    - Prepares training (`X` and `y`) and testing datasets (`X_test`).
#
# 3. **Pipeline Setup** 🔄
#    - Creates a **preprocessing pipeline** for feature transformation.
#
# 4. **Model Training** 🏋️‍♂️
#    - Trains models using the `train_and_evaluate` function.
#    - Obtains **results**, **models**, **best parameters**, and **study data**.
#
# 5. **Best Hyperparameters** 📊
#    - Prints the **best hyperparameters** for each model after training.
#
# 6. **Prediction and Visualization** 📈
#    - Generates **predictions** on the **validation** and **test sets**.
#    - Calculates the **optimal threshold** using the **ROC curve** and visualizes the predictions.
#    - Saves predictions to a CSV file (`submission_{model_name}.csv`).
#
# 7. **Model Saving** 💾
#    - Saves the **best-performing model** as `best_model.pkl`.
#
# ## 🎯 Train Data in Pipeline Before Training 🎯
#
# | Column Name             | Description                                                                 | Data Type |
# |-------------------------|-----------------------------------------------------------------------------|-----------|
# | pressure                | The atmospheric pressure at the given time, measured in hPa.                | Float     |
# | maxtemp                 | The maximum temperature for the day in degrees Celsius.                     | Float     |
# | temparature             | The average temperature for the day in degrees Celsius.                     | Float     |
# | mintemp                 | The minimum temperature for the day in degrees Celsius.                     | Float     |
# | dewpoint                | The dewpoint temperature in degrees Celsius, indicating moisture in the air.| Float     |
# | humidity                | The humidity level in percentage, indicating the amount of moisture in the air.| Float     |
# | cloud                   | The percentage of cloud cover for the day.                                  | Float     |
# | sunshine                | The number of hours of sunshine during the day.                             | Float     |
# | winddirection           | The wind direction, measured in degrees from North (0° to 360°).            | Float     |
# | windspeed               | The wind speed in km/h.                                                     | Float     |
# | poly_humidity^2        | The square of the humidity value.                                           | Float     |
# | poly_humidity pressure | The product of the humidity and pressure values.                            | Float     |
# | poly_humidity windspeed| The product of the humidity and windspeed values.                           | Float     |
# | poly_humidity cloud    | The product of the humidity and cloud values.                               | Float     |
# | poly_pressure^2        | The square of the pressure value.                                           | Float     |
# | poly_pressure windspeed| The product of the pressure and windspeed values.                           | Float     |
# | poly_pressure cloud    | The product of the pressure and cloud values.                               | Float     |
# | poly_windspeed^2       | The square of the windspeed value.                                          | Float     |
# | poly_windspeed cloud   | The product of the windspeed and cloud values.                              | Float     |
# | poly_cloud^2            | The square of the cloud value.                                              | Float     |

# %%
# ======================
# Main Execution
# ======================
if __name__ == "__main__":
    # Load and preprocess data
    train, test, extra = load_data()
    
    # Process extra data
    extra.columns = extra.columns.str.replace(' ', '')
    extra['rainfall'] = extra['rainfall'].map({'no': 0, 'yes': 1})
    extra = extra.dropna().reset_index(drop=True)
    
    # Merge datasets
    train['source'] = 'main'
    extra['source'] = 'extra'
    test['source'] = 'test'
    
    full_data = pd.concat([train, extra, test], axis=0).reset_index(drop=True)
    
    # Feature engineering
    full_data = feature_engineering(full_data)
    
    # Split data
    train_data = full_data[full_data['date'] < '2021-01-01']
    test_data = full_data[full_data['source'] == 'test']
    
    # Define features
    numeric_features = [
        'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
        'humidity', 'cloud', 'sunshine', 'windspeed', 'day_of_year',
        'month', 'is_weekend', 'day_sin', 'day_cos', 'pressure_rolling_mean',
        'pressure_rolling_std', 'pressure_diff', 'temp_range', 'temp_ewm',
        'temp_change', 'temp_humidity_interaction', 'dewpoint_depression',
        'rh_approx', 'svp', 'abs_humidity', 'sky_opacity', 'sunshine_pct',
        'cloud_sun_ratio', 'interaction', 'winddir_sin', 'winddir_cos'
    ] + [col for col in full_data.columns if col.startswith('poly_')]

    
    X = train_data[numeric_features]
    y = train_data['rainfall']
    X_test = test_data[numeric_features]

    train_data.drop(columns=['day'], inplace=True)
    display(train_data.head())
    
    # Create preprocessing pipeline
    preprocessor = create_pipeline(numeric_features)
    
    # Train models
    results, models, best_params, studies = train_and_evaluate(X, y, preprocessor)
    
    # Print best hyperparameters
    print("\n\n" + "="*60)
    print("Best Hyperparameters")
    print("="*60)
    for model_name, params in best_params.items():
        print(f"\n{model_name}:")
        if 'solver_penalty' in params:
            solver, penalty = params.pop('solver_penalty')
            params['solver'] = solver
            params['penalty'] = penalty
        for param, value in params.items():
            if isinstance(value, float):
                print(f"  {param:20} = {value:.6f}")
            else:
                print(f"  {param:20} = {value}")
    print("="*60)

    
    # Generate predictions and visualize
    if models:
        best_score = -1
        best_model_name = ''
        for model_name, model in models.items():
            print(f"\nGenerating predictions with {model_name}")
            try:
                # Get validation predictions from training
                val_probs = model.predict_proba(X)[:, 1]
                
                # Calculate optimal threshold from validation set
                print("\nCalculating Optimal Threshold from ROC Curve...")
                roc_fig, optimal_threshold = plot_roc_curve(y, val_probs)
                roc_fig.show()
                
                # Generate test set predictions
                test_probs = model.predict_proba(X_test)[:, 1]
                
                # Visualize test set predictions using optimal threshold
                print("\nVisualizing Logistic Regression Predictions with Optimal Threshold...")
                plot_logistic_predictions(y, val_probs, optimal_threshold)  # Use validation set for visualization
                
                # Save predictions
                submission = pd.DataFrame({'id': test.index, 'rainfall': test_probs})
                submission.to_csv(f'submission_{model_name}.csv', index=False)
                print(f"Saved submission_{model_name}.csv")
                
                if results[model_name] > best_score:
                    best_score = results[model_name]
                    best_model_name = model_name
                    best_probs = test_probs
            except Exception as e:
                print(f"Error generating predictions for {model_name}: {str(e)}")

        # Save best model
        if best_model_name:
            joblib.dump(models[best_model_name], 'best_model.pkl')
            print(f"\nSaved best model ({best_model_name}) as best_model.pkl")
    else:
        print("\nNo valid models trained. Check error messages above.")
# Out:
#    pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0    1017.4     21.2         20.6     19.9      19.4      87.0   88.0
# 1    1019.5     16.2         16.9     15.8      15.4      95.0   91.0
# 2    1024.1     19.4         16.1     14.6       9.3      75.0   47.0
# 3    1013.4     18.1         17.8     16.9      16.8      95.0   95.0
# 4    1021.8     21.3         18.4     15.2       9.6      52.0   45.0
#
#    sunshine  winddirection  windspeed  ...  poly_humidity^2  \
# 0       1.1           60.0       17.2  ...           7569.0
# 1       0.0           50.0       21.9  ...           9025.0
# 2       8.3           70.0       18.1  ...           5625.0
# 3       0.0           60.0       35.6  ...           9025.0
# 4       3.6           40.0       24.8  ...           2704.0
#
#   poly_humidity pressure poly_humidity windspeed  poly_humidity cloud  \
# 0                88513.8                  1496.4               7656.0
# 1                96852.5                  2080.5               8645.0
# 2                76807.5                  1357.5               3525.0
# 3                96273.0                  3382.0               9025.0
# 4                53133.6                  1289.6               2340.0
#
#    poly_pressure^2  poly_pressure windspeed  poly_pressure cloud  \
# 0       1035102.76                 17499.28              89531.2
# 1       1039380.25                 22327.05              92774.5
# 2       1048780.81                 18536.21              48132.7
# 3       1026979.56                 36077.04              96273.0
# 4       1044075.24                 25340.64              45981.0
#
#    poly_windspeed^2  poly_windspeed cloud  poly_cloud^2
# 0            295.84                1513.6        7744.0
# 1            479.61                1992.9        8281.0
# 2            327.61                 850.7        2209.0
# 3           1267.36                3382.0        9025.0
# 4            615.04                1116.0        2025.0
#
# [5 rows x 56 columns]
# [I 2025-03-10 08:58:44,459] A new study created in memory with name: no-name-d9337528-906e-446b-9945-6632348677db
# ========================================
# Tuning LogisticRegression
# ========================================
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [I 2025-03-10 08:58:46,515] Trial 0 finished with value: 0.8898071941873231 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.9047071957568393, 'max_iter': 200, 'class_weight': None, 'tol': 7.068974950624607e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 0 with value: 0.8898071941873231.
# [I 2025-03-10 08:58:46,754] Trial 1 finished with value: 0.8950220580659838 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.039777828308111905, 'max_iter': 3003, 'class_weight': 'balanced', 'tol': 4.809461967501575e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 1 with value: 0.8950220580659838.
# [I 2025-03-10 08:58:47,720] Trial 2 finished with value: 0.8894766518079609 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.43416618003617374, 'max_iter': 1627, 'class_weight': 'balanced', 'tol': 5.4880470007660465e-06, 'fit_intercept': True, 'warm_start': True}. Best is trial 1 with value: 0.8950220580659838.
# [I 2025-03-10 08:58:47,801] Trial 3 finished with value: 0.8998885285135014 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0031424855318831642, 'max_iter': 1476, 'class_weight': None, 'tol': 0.0016172900811143157, 'fit_intercept': False, 'warm_start': True}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:51,448] Trial 4 finished with value: 0.8842411955115125 and parameters: {'solver_penalty': ('saga', 'none'), 'C': 0.23072087378099004, 'max_iter': 1721, 'class_weight': 'balanced', 'tol': 1.99863407785289e-05, 'fit_intercept': True, 'warm_start': True}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:51,550] Trial 5 finished with value: 0.8976010920727397 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 5.6916736298998865e-05, 'max_iter': 254, 'class_weight': None, 'tol': 0.00010821382910613992, 'fit_intercept': True, 'warm_start': False}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:51,653] Trial 6 finished with value: 0.8980332456468896 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0002022974517542948, 'max_iter': 4474, 'class_weight': 'balanced', 'tol': 0.003840300419098858, 'fit_intercept': True, 'warm_start': False}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:51,897] Trial 7 finished with value: 0.8886848328858488 and parameters: {'solver_penalty': ('saga', 'none'), 'C': 0.0018298712093870887, 'max_iter': 2642, 'class_weight': None, 'tol': 0.007711312991331112, 'fit_intercept': True, 'warm_start': True}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:52,343] Trial 8 finished with value: 0.8969949916785396 and parameters: {'solver_penalty': ('saga', 'l1'), 'C': 0.026678986172428084, 'max_iter': 4930, 'class_weight': 'balanced', 'tol': 0.0011129571947046015, 'fit_intercept': False, 'warm_start': False}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:52,425] Trial 9 finished with value: 0.8967775631407093 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 1.3065162102672634e-05, 'max_iter': 2609, 'class_weight': 'balanced', 'tol': 4.982711200081135e-06, 'fit_intercept': True, 'warm_start': True, 'intercept_scaling': 3.4765568753975593}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:52,537] Trial 10 finished with value: 0.8997797669935921 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0035163631108754323, 'max_iter': 1331, 'class_weight': None, 'tol': 0.0003633741340913686, 'fit_intercept': False, 'warm_start': True}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:52,872] Trial 11 finished with value: 0.8791432264300278 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 42.53369717585125, 'max_iter': 1234, 'class_weight': None, 'tol': 0.00029499719873019855, 'fit_intercept': False, 'warm_start': True}. Best is trial 3 with value: 0.8998885285135014.
# [I 2025-03-10 08:58:52,981] Trial 12 finished with value: 0.9002729847646019 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0016904555315472528, 'max_iter': 884, 'class_weight': None, 'tol': 0.000733014271820989, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,090] Trial 13 finished with value: 0.8999796070557882 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.0007113517740917337, 'max_iter': 908, 'class_weight': None, 'tol': 0.0015461037799015815, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,209] Trial 14 finished with value: 0.8993100251268874 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.0002987436686487355, 'max_iter': 722, 'class_weight': None, 'tol': 0.0006683920388975738, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,319] Trial 15 finished with value: 0.8999949038823584 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.000590690578210294, 'max_iter': 3831, 'class_weight': None, 'tol': 0.00010145858556223653, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,553] Trial 16 finished with value: 0.8955179446998283 and parameters: {'solver_penalty': ('saga', 'elasticnet'), 'C': 0.02512438105787543, 'max_iter': 3650, 'class_weight': None, 'tol': 3.0520148263734066e-05, 'fit_intercept': False, 'warm_start': True, 'l1_ratio': 0.31300585429994227}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,654] Trial 17 finished with value: 0.5 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 4.47207235619313e-05, 'max_iter': 3829, 'class_weight': None, 'tol': 1.0446251525877387e-06, 'fit_intercept': False, 'warm_start': True, 'intercept_scaling': 9.798500346844168}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,821] Trial 18 finished with value: 0.8820280592137404 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 10.412358831125514, 'max_iter': 3320, 'class_weight': None, 'tol': 0.00015063773013868762, 'fit_intercept': False, 'warm_start': False}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:53,958] Trial 19 finished with value: 0.8112003846948662 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 0.006451820918855636, 'max_iter': 2161, 'class_weight': None, 'tol': 6.677970008896302e-05, 'fit_intercept': False, 'warm_start': True, 'intercept_scaling': 0.4207575647690591}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,058] Trial 20 finished with value: 0.5 and parameters: {'solver_penalty': ('saga', 'l1'), 'C': 0.0001919276256717802, 'max_iter': 4523, 'class_weight': None, 'tol': 4.959915345753532e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,169] Trial 21 finished with value: 0.9000921677351977 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.0008200001522981811, 'max_iter': 769, 'class_weight': None, 'tol': 0.0026514296559290336, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,276] Trial 22 finished with value: 0.8999702613165773 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.0006904176751786387, 'max_iter': 1975, 'class_weight': None, 'tol': 0.006090721629568251, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,387] Trial 23 finished with value: 0.8978478735332562 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.008344036158373501, 'max_iter': 780, 'class_weight': None, 'tol': 0.0033329776692956653, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,487] Trial 24 finished with value: 0.5 and parameters: {'solver_penalty': ('saga', 'elasticnet'), 'C': 0.0007713293481681541, 'max_iter': 2209, 'class_weight': None, 'tol': 0.0005191443537934136, 'fit_intercept': False, 'warm_start': True, 'l1_ratio': 0.9438658020309545}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,589] Trial 25 finished with value: 0.8976148236131211 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 4.128071289128516e-05, 'max_iter': 458, 'class_weight': None, 'tol': 0.000239877275064594, 'fit_intercept': False, 'warm_start': True, 'intercept_scaling': 9.70676006852787}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,702] Trial 26 finished with value: 0.8985754412829265 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.00014138572647194242, 'max_iter': 4048, 'class_weight': None, 'tol': 0.0023522259763855214, 'fit_intercept': False, 'warm_start': False}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,821] Trial 27 finished with value: 0.8965565275174334 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.012847238440294112, 'max_iter': 1082, 'class_weight': None, 'tol': 0.0007681833229773795, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:54,940] Trial 28 finished with value: 0.8924365715362722 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.07538408906085388, 'max_iter': 2978, 'class_weight': None, 'tol': 0.00984715163901384, 'fit_intercept': False, 'warm_start': True}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:55,041] Trial 29 finished with value: 0.9002179744192468 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0012928779534985197, 'max_iter': 305, 'class_weight': None, 'tol': 1.34913431960413e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:55,142] Trial 30 finished with value: 0.9001777508385189 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0018689503525009523, 'max_iter': 113, 'class_weight': None, 'tol': 1.7352141797620774e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 12 with value: 0.9002729847646019.
# [I 2025-03-10 08:58:55,243] Trial 31 finished with value: 0.9002765067087972 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001738844146771426, 'max_iter': 129, 'class_weight': None, 'tol': 1.1696766705514477e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:55,353] Trial 32 finished with value: 0.8999753896623254 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.002375037721708395, 'max_iter': 127, 'class_weight': None, 'tol': 1.3982268039410555e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:55,475] Trial 33 finished with value: 0.8919036361245631 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.10854649134852132, 'max_iter': 427, 'class_weight': None, 'tol': 2.0186830292812416e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:55,575] Trial 34 finished with value: 0.8992693896255803 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001757600297970115, 'max_iter': 427, 'class_weight': 'balanced', 'tol': 1.1221165819487408e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:55,743] Trial 35 finished with value: 0.8894846322580559 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 1.0464969865421958, 'max_iter': 124, 'class_weight': None, 'tol': 2.890292876563332e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:55,897] Trial 36 finished with value: 0.8964143390708348 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.013733353534066227, 'max_iter': 511, 'class_weight': 'balanced', 'tol': 2.9264072436139514e-05, 'fit_intercept': True, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:56,006] Trial 37 finished with value: 0.898340964435526 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.006870603248715449, 'max_iter': 1064, 'class_weight': None, 'tol': 8.85077450239833e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:56,117] Trial 38 finished with value: 0.8978857131583176 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0001046892526365603, 'max_iter': 1632, 'class_weight': None, 'tol': 1.876817956413811e-05, 'fit_intercept': True, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:57,406] Trial 39 finished with value: 0.8867083311254822 and parameters: {'solver_penalty': ('saga', 'none'), 'C': 0.0037322404145706365, 'max_iter': 610, 'class_weight': 'balanced', 'tol': 6.70492844265087e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:57,965] Trial 40 finished with value: 0.8888995496375808 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 1.4624931074109464, 'max_iter': 207, 'class_weight': None, 'tol': 3.305010322085373e-06, 'fit_intercept': True, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,078] Trial 41 finished with value: 0.9001102202847063 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0013635777251445153, 'max_iter': 910, 'class_weight': None, 'tol': 4.081481946539869e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,200] Trial 42 finished with value: 0.9002706679202042 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001718496641779404, 'max_iter': 918, 'class_weight': None, 'tol': 4.366783326344013e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,328] Trial 43 finished with value: 0.8996038001161024 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00041770379968476216, 'max_iter': 314, 'class_weight': None, 'tol': 1.7527595332800032e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,452] Trial 44 finished with value: 0.8997216750953262 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00364987708920187, 'max_iter': 1177, 'class_weight': None, 'tol': 6.264906677914132e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,615] Trial 45 finished with value: 0.8966222227578633 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.018797664903155716, 'max_iter': 1456, 'class_weight': 'balanced', 'tol': 0.0001651136400760855, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,739] Trial 46 finished with value: 0.8944471729628777 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.05486400050914198, 'max_iter': 567, 'class_weight': None, 'tol': 2.5514045111575367e-05, 'fit_intercept': True, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,841] Trial 47 finished with value: 0.5 and parameters: {'solver_penalty': ('saga', 'l1'), 'C': 0.00037956325136442653, 'max_iter': 102, 'class_weight': None, 'tol': 5.732942184835371e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:58,944] Trial 48 finished with value: 0.8968331624103687 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 1.218298567759884e-05, 'max_iter': 862, 'class_weight': None, 'tol': 9.273667181999613e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:58:59,063] Trial 49 finished with value: 0.9001596288140137 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.0013455540437609548, 'max_iter': 1805, 'class_weight': None, 'tol': 1.3241603796176132e-05, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 5.618954204473397}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,069] Trial 50 finished with value: 0.8856911681314115 and parameters: {'solver_penalty': ('saga', 'none'), 'C': 7.884683236734879e-05, 'max_iter': 1379, 'class_weight': 'balanced', 'tol': 7.34584268648503e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,177] Trial 51 finished with value: 0.9002288629573808 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.0014683715745644316, 'max_iter': 340, 'class_weight': None, 'tol': 1.3773490059290425e-05, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 5.492910595140073}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,293] Trial 52 finished with value: 0.899871365470957 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.0030250646099866693, 'max_iter': 287, 'class_weight': None, 'tol': 3.510243610895843e-05, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 5.993556023174547}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,411] Trial 53 finished with value: 0.8986210891960716 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.006083858040059188, 'max_iter': 665, 'class_weight': None, 'tol': 3.819018242450492e-06, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 2.9817234893928215}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,516] Trial 54 finished with value: 0.5 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 0.00028526214946355047, 'max_iter': 324, 'class_weight': None, 'tol': 2.3102499067493986e-05, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 7.461694727001856}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,794] Trial 55 finished with value: 0.8943967237311042 and parameters: {'solver_penalty': ('saga', 'elasticnet'), 'C': 0.03420917339790018, 'max_iter': 970, 'class_weight': None, 'tol': 7.70760389911076e-06, 'fit_intercept': False, 'warm_start': False, 'l1_ratio': 0.005661421379809295}. Best is trial 31 with value: 0.9002765067087972.
# [I 2025-03-10 08:59:02,926] Trial 56 finished with value: 0.9003025117022819 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0010736585794426919, 'max_iter': 715, 'class_weight': None, 'tol': 1.469949709774896e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,049] Trial 57 finished with value: 0.8991205428843267 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.001009111854736688, 'max_iter': 739, 'class_weight': None, 'tol': 4.2586025178340995e-05, 'fit_intercept': True, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,171] Trial 58 finished with value: 0.8972263275067117 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 2.4829255489031524e-05, 'max_iter': 1132, 'class_weight': None, 'tol': 0.00012409483823484216, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,303] Trial 59 finished with value: 0.8997819892086678 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.00046398101710526336, 'max_iter': 1320, 'class_weight': None, 'tol': 1.0589754029695197e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,410] Trial 60 finished with value: 0.8989469148218776 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.0002396674357543929, 'max_iter': 454, 'class_weight': None, 'tol': 4.425864996002727e-06, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 3.0202800816670003}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,514] Trial 61 finished with value: 0.9001868609696737 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001882372242945118, 'max_iter': 577, 'class_weight': None, 'tol': 1.6763736906539646e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,619] Trial 62 finished with value: 0.8994857711062796 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.004269743319885638, 'max_iter': 633, 'class_weight': None, 'tol': 1.3496670927843636e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,746] Trial 63 finished with value: 0.9002340833398742 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0009782729263976327, 'max_iter': 852, 'class_weight': None, 'tol': 2.0886410571924243e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,869] Trial 64 finished with value: 0.89999577022811 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.000714244738293358, 'max_iter': 941, 'class_weight': None, 'tol': 5.603483851685755e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:03,993] Trial 65 finished with value: 0.8986358689611755 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.00017029335203061315, 'max_iter': 344, 'class_weight': None, 'tol': 7.769394637869822e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,137] Trial 66 finished with value: 0.8969322772812806 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.01114075632469442, 'max_iter': 2389, 'class_weight': None, 'tol': 2.3427997646399585e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,239] Trial 67 finished with value: 0.5 and parameters: {'solver_penalty': ('saga', 'l1'), 'C': 0.0010768971706810178, 'max_iter': 796, 'class_weight': None, 'tol': 2.9137678656087435e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,346] Trial 68 finished with value: 0.5 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 0.0005230423340794837, 'max_iter': 1286, 'class_weight': None, 'tol': 6.485234654657364e-06, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 0.29201978882484436}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,480] Trial 69 finished with value: 0.8984020408841692 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.005494157889332941, 'max_iter': 1563, 'class_weight': 'balanced', 'tol': 3.9205643645706986e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,630] Trial 70 finished with value: 0.5762262128115786 and parameters: {'solver_penalty': ('saga', 'elasticnet'), 'C': 0.002063070806307097, 'max_iter': 1097, 'class_weight': None, 'tol': 0.0013496930178701072, 'fit_intercept': False, 'warm_start': False, 'l1_ratio': 0.9965458180037977}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,735] Trial 71 finished with value: 0.8999836464462856 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.002271811197205992, 'max_iter': 540, 'class_weight': None, 'tol': 1.6606588751488964e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,839] Trial 72 finished with value: 0.9001659243524577 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0012226276451316807, 'max_iter': 660, 'class_weight': None, 'tol': 1.083181983552334e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:04,954] Trial 73 finished with value: 0.8972924557322317 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.010263144163293698, 'max_iter': 407, 'class_weight': None, 'tol': 2.0547446257893853e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:05,088] Trial 74 finished with value: 0.8999847269398009 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0007529572979419918, 'max_iter': 272, 'class_weight': None, 'tol': 2.4281578987380853e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:05,195] Trial 75 finished with value: 0.8999547373292147 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.002728703491348805, 'max_iter': 969, 'class_weight': None, 'tol': 1.39084888063685e-05, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 7.69989656988541}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:05,298] Trial 76 finished with value: 0.9001940393156497 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001457127957393515, 'max_iter': 799, 'class_weight': None, 'tol': 8.259247264949088e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,127] Trial 77 finished with value: 0.8851650412093729 and parameters: {'solver_penalty': ('saga', 'none'), 'C': 81.16025358541734, 'max_iter': 824, 'class_weight': None, 'tol': 7.97774370804201e-06, 'fit_intercept': True, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,230] Trial 78 finished with value: 0.8991662677402035 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00025367584024584266, 'max_iter': 219, 'class_weight': None, 'tol': 4.693167598978673e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,334] Trial 79 finished with value: 0.8983118051217451 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00010493181201670613, 'max_iter': 724, 'class_weight': None, 'tol': 0.0004194601021313837, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,470] Trial 80 finished with value: 0.8995468914758705 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.00037095031633682706, 'max_iter': 1012, 'class_weight': None, 'tol': 1.524838661831524e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,575] Trial 81 finished with value: 0.9002765067087972 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0017395792621384876, 'max_iter': 575, 'class_weight': None, 'tol': 3.192383732309872e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,679] Trial 82 finished with value: 0.9001856587905264 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0015829399315145153, 'max_iter': 3002, 'class_weight': None, 'tol': 8.366088173801283e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,791] Trial 83 finished with value: 0.8992192789293231 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0045676015356492464, 'max_iter': 525, 'class_weight': None, 'tol': 4.9865468918393045e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:07,905] Trial 84 finished with value: 0.9002608721691276 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.000951887588867147, 'max_iter': 420, 'class_weight': None, 'tol': 1.101193493248558e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,013] Trial 85 finished with value: 0.8988713176228768 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0005812364017570444, 'max_iter': 427, 'class_weight': 'balanced', 'tol': 3.039195590777674e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,132] Trial 86 finished with value: 0.8979677930038455 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.007755953077732142, 'max_iter': 209, 'class_weight': None, 'tol': 1.1707301672496274e-05, 'fit_intercept': False, 'warm_start': True, 'intercept_scaling': 4.31777759075231}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,245] Trial 87 finished with value: 0.8957575164648033 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.01796149210000329, 'max_iter': 3341, 'class_weight': None, 'tol': 2.1898294748580746e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,349] Trial 88 finished with value: 0.5 and parameters: {'solver_penalty': ('saga', 'l1'), 'C': 0.000946263483704186, 'max_iter': 1208, 'class_weight': None, 'tol': 0.005011147281077134, 'fit_intercept': True, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,485] Trial 89 finished with value: 0.8997543426902773 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.0034810917930912775, 'max_iter': 390, 'class_weight': None, 'tol': 2.6544344691565362e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,595] Trial 90 finished with value: 0.5 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 0.0008761510199701307, 'max_iter': 106, 'class_weight': None, 'tol': 0.00022459840215057335, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 7.184804349148721}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,700] Trial 91 finished with value: 0.9001595004043697 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0013865854658321392, 'max_iter': 868, 'class_weight': None, 'tol': 9.152387907782125e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,803] Trial 92 finished with value: 0.8999678057728706 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0022902781483651554, 'max_iter': 721, 'class_weight': None, 'tol': 6.435841522437278e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:08,951] Trial 93 finished with value: 0.8910320746382082 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.3004000764814761, 'max_iter': 549, 'class_weight': None, 'tol': 1.573322061103475e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:09,057] Trial 94 finished with value: 0.8995500940409649 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00034410903137861286, 'max_iter': 297, 'class_weight': None, 'tol': 3.473950263749726e-05, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:09,274] Trial 95 finished with value: 0.8858588178797753 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 3.1190545750761616, 'max_iter': 840, 'class_weight': None, 'tol': 9.867162880245253e-06, 'fit_intercept': False, 'warm_start': True}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:09,400] Trial 96 finished with value: 0.9000107077129469 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.000575837489957129, 'max_iter': 653, 'class_weight': None, 'tol': 1.2399781325290765e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:09,542] Trial 97 finished with value: 0.5761100687929956 and parameters: {'solver_penalty': ('saga', 'elasticnet'), 'C': 0.0012765611001246866, 'max_iter': 470, 'class_weight': None, 'tol': 5.6535994913548495e-06, 'fit_intercept': False, 'warm_start': True, 'l1_ratio': 0.5788311360337963}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:11,668] Trial 98 finished with value: 0.8860662557386343 and parameters: {'solver_penalty': ('saga', 'none'), 'C': 0.0030512578604414455, 'max_iter': 1055, 'class_weight': 'balanced', 'tol': 8.017217469436268e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:11,769] Trial 99 finished with value: 0.8985744686713788 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00014481644519436716, 'max_iter': 244, 'class_weight': None, 'tol': 1.9791739386310174e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:11,882] Trial 100 finished with value: 0.8991133010517854 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 0.004571276797392957, 'max_iter': 1860, 'class_weight': None, 'tol': 1.6133602393402528e-05, 'fit_intercept': True, 'warm_start': True, 'intercept_scaling': 2.3935910632707444}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:11,987] Trial 101 finished with value: 0.9001587475701276 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0016124834122985554, 'max_iter': 598, 'class_weight': None, 'tol': 1.8805942987236636e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,094] Trial 102 finished with value: 0.9002430853759323 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0018145711905941597, 'max_iter': 759, 'class_weight': None, 'tol': 1.439469383720153e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,201] Trial 103 finished with value: 0.8999943129984652 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0024834786475088203, 'max_iter': 2814, 'class_weight': None, 'tol': 4.625562771405145e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,310] Trial 104 finished with value: 0.9002677032388124 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010052704001511825, 'max_iter': 933, 'class_weight': None, 'tol': 0.0008553797174607874, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,437] Trial 105 finished with value: 0.9001748352580641 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 0.0008665029478066735, 'max_iter': 1424, 'class_weight': None, 'tol': 0.000853316089078371, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,555] Trial 106 finished with value: 0.8998621534014761 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0004771618293843775, 'max_iter': 4682, 'class_weight': None, 'tol': 0.0011142111642660796, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,660] Trial 107 finished with value: 0.8999698497326424 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0006778524847446326, 'max_iter': 357, 'class_weight': None, 'tol': 0.0006206484780618305, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,779] Trial 108 finished with value: 0.8988265654079927 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.005690042468659679, 'max_iter': 940, 'class_weight': None, 'tol': 3.4826639530809584e-05, 'fit_intercept': False, 'warm_start': False}. Best is trial 56 with value: 0.9003025117022819.
# [I 2025-03-10 08:59:12,889] Trial 109 finished with value: 0.9003087129524143 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010635458917245817, 'max_iter': 738, 'class_weight': None, 'tol': 0.0017937834790514627, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:12,999] Trial 110 finished with value: 0.8987943260085061 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00021747533057338452, 'max_iter': 1136, 'class_weight': None, 'tol': 0.002291525294369227, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,106] Trial 111 finished with value: 0.9002578424820641 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010431879948717801, 'max_iter': 718, 'class_weight': None, 'tol': 0.0031548860157330797, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,214] Trial 112 finished with value: 0.9002703553005469 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001098619579388568, 'max_iter': 743, 'class_weight': None, 'tol': 0.003042205888431743, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,319] Trial 113 finished with value: 0.9002240466072466 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010489366035596238, 'max_iter': 724, 'class_weight': None, 'tol': 0.0019397587527515245, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,441] Trial 114 finished with value: 0.9000346656338405 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.002075256521228506, 'max_iter': 1210, 'class_weight': None, 'tol': 0.003137544344140319, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,552] Trial 115 finished with value: 0.8996644089590419 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00043219771240054795, 'max_iter': 1018, 'class_weight': None, 'tol': 0.004292458736511315, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,661] Trial 116 finished with value: 0.8999367667149627 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0006478174061845802, 'max_iter': 835, 'class_weight': None, 'tol': 0.006154885978286672, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,763] Trial 117 finished with value: 0.8993334188724159 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0003057315718377664, 'max_iter': 658, 'class_weight': None, 'tol': 0.0016681886221022952, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:13,882] Trial 118 finished with value: 0.8990728850752298 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0029854495956191723, 'max_iter': 889, 'class_weight': 'balanced', 'tol': 0.003108145020569125, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,001] Trial 119 finished with value: 0.9002766373940879 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010040280801955736, 'max_iter': 506, 'class_weight': None, 'tol': 0.0012451210441680883, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,109] Trial 120 finished with value: 0.9002917576212344 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010575566280333147, 'max_iter': 514, 'class_weight': None, 'tol': 0.0011931339248380168, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,219] Trial 121 finished with value: 0.9001708125848944 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0018806719236363803, 'max_iter': 638, 'class_weight': None, 'tol': 0.0009839335415692187, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,339] Trial 122 finished with value: 0.9002577276945214 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010395501176245867, 'max_iter': 538, 'class_weight': None, 'tol': 0.001360563812791768, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,452] Trial 123 finished with value: 0.9002946665022569 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0010755527185604644, 'max_iter': 485, 'class_weight': None, 'tol': 0.00135353608025701, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,561] Trial 124 finished with value: 0.8998471403727416 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0005162067691770268, 'max_iter': 456, 'class_weight': None, 'tol': 0.0019689273876003477, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,673] Trial 125 finished with value: 0.8999178004955404 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0007349889465252889, 'max_iter': 497, 'class_weight': None, 'tol': 0.0006542957786513925, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:14,785] Trial 126 finished with value: 0.8992377484148015 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0011953742255851774, 'max_iter': 215, 'class_weight': None, 'tol': 0.0011803675770992897, 'fit_intercept': True, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,029] Trial 127 finished with value: 0.7279651479711029 and parameters: {'solver_penalty': ('saga', 'l1'), 'C': 0.003792535951355632, 'max_iter': 712, 'class_weight': None, 'tol': 0.002587544484922965, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,136] Trial 128 finished with value: 0.9000666666473837 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.002573536744980153, 'max_iter': 596, 'class_weight': None, 'tol': 0.0008716469649365407, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,257] Trial 129 finished with value: 0.9001070003112428 and parameters: {'solver_penalty': ('saga', 'l2'), 'C': 0.0008320534652676648, 'max_iter': 412, 'class_weight': None, 'tol': 0.0019577585182121286, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,365] Trial 130 finished with value: 0.8992236060847404 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0002828798068157749, 'max_iter': 990, 'class_weight': None, 'tol': 0.001437570023087155, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,472] Trial 131 finished with value: 0.9002325155793814 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001024743811092322, 'max_iter': 528, 'class_weight': None, 'tol': 0.0012919496102500154, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,583] Trial 132 finished with value: 0.9001526278158923 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0014055298846595093, 'max_iter': 558, 'class_weight': None, 'tol': 0.0017330090527832211, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,694] Trial 133 finished with value: 0.8995871045393322 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0003880640155827039, 'max_iter': 789, 'class_weight': None, 'tol': 0.00040661392704066304, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,808] Trial 134 finished with value: 0.5 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 0.0005689968889302968, 'max_iter': 351, 'class_weight': None, 'tol': 0.0005298749292572512, 'fit_intercept': False, 'warm_start': False, 'intercept_scaling': 1.5877612207378662}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:15,918] Trial 135 finished with value: 0.9002538341434958 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0011225343510693493, 'max_iter': 479, 'class_weight': None, 'tol': 0.00240585341022675, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:16,036] Trial 136 finished with value: 0.9000828016428872 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.002043296050011008, 'max_iter': 4155, 'class_weight': None, 'tol': 0.0008175056959937632, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:16,151] Trial 137 finished with value: 0.5 and parameters: {'solver_penalty': ('saga', 'elasticnet'), 'C': 0.0007492658086389659, 'max_iter': 182, 'class_weight': None, 'tol': 0.003514590357133375, 'fit_intercept': False, 'warm_start': False, 'l1_ratio': 0.595183198952554}. Best is trial 109 with value: 0.9003087129524143.
# [I 2025-03-10 08:59:16,271] Trial 138 finished with value: 0.9002910274948723 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001677533525433627, 'max_iter': 668, 'class_weight': None, 'tol': 0.001014507384407828, 'fit_intercept': False, 'warm_start': False}. Best is trial 109 with value: 0.9003087129524143.
# ...
# [I 2025-03-10 09:01:52,704] Trial 995 finished with value: 0.8997252783935641 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.00045649949654742896, 'max_iter': 1096, 'class_weight': None, 'tol': 0.0013967984753193044, 'fit_intercept': False, 'warm_start': False}. Best is trial 601 with value: 0.9003186748746039.
# [I 2025-03-10 09:01:52,877] Trial 996 finished with value: 0.9001425526623207 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0013593951606877526, 'max_iter': 572, 'class_weight': None, 'tol': 5.53666173644788e-06, 'fit_intercept': False, 'warm_start': False}. Best is trial 601 with value: 0.9003186748746039.
# [I 2025-03-10 09:01:53,066] Trial 997 finished with value: 0.8999877490522057 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.0007121632644946799, 'max_iter': 697, 'class_weight': None, 'tol': 0.0011843606973706861, 'fit_intercept': False, 'warm_start': False}. Best is trial 601 with value: 0.9003186748746039.
# [I 2025-03-10 09:01:53,256] Trial 998 finished with value: 0.8991156887876945 and parameters: {'solver_penalty': ('sag', 'l2'), 'C': 0.0009299374945085898, 'max_iter': 427, 'class_weight': None, 'tol': 0.0024527272831538884, 'fit_intercept': True, 'warm_start': False}. Best is trial 601 with value: 0.9003186748746039.
# [I 2025-03-10 09:01:53,457] Trial 999 finished with value: 0.9002288629573808 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 0.001469798205912338, 'max_iter': 963, 'class_weight': None, 'tol': 0.0016494482183164172, 'fit_intercept': False, 'warm_start': False}. Best is trial 601 with value: 0.9003186748746039.
# Fold 1: 0.9113
# Fold 2: 0.9205
# Fold 3: 0.9019
# Fold 4: 0.8832
# Fold 5: 0.8848
#
# Aggregate Metrics:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7df491c7-ac64-4651-9e15-5c6936d228b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7df491c7-ac64-4651-9e15-5c6936d228b1")) {                    Plotly.newPlot(                        "7df491c7-ac64-4651-9e15-5c6936d228b1",                        [{"mode":"lines","name":"ROC Curve (AUC = 0.89)","x":[0.0,0.0,0.0,0.0022675736961451248,0.0022675736961451248,0.0045351473922902496,0.0045351473922902496,0.006802721088435374,0.006802721088435374,0.009070294784580499,0.009070294784580499,0.011337868480725623,0.011337868480725623,0.013605442176870748,0.013605442176870748,0.015873015873015872,0.015873015873015872,0.018140589569160998,0.018140589569160998,0.02040816326530612,0.02040816326530612,0.022675736961451247,0.022675736961451247,0.024943310657596373,0.024943310657596373,0.027210884353741496,0.027210884353741496,0.02947845804988662,0.02947845804988662,0.031746031746031744,0.031746031746031744,0.034013605442176874,0.034013605442176874,0.036281179138321996,0.036281179138321996,0.03854875283446712,0.03854875283446712,0.04081632653061224,0.04081632653061224,0.04308390022675737,0.04308390022675737,0.045351473922902494,0.045351473922902494,0.047619047619047616,0.047619047619047616,0.049886621315192746,0.049886621315192746,0.05215419501133787,0.05215419501133787,0.05442176870748299,0.05442176870748299,0.05668934240362812,0.05668934240362812,0.05895691609977324,0.05895691609977324,0.061224489795918366,0.061224489795918366,0.06349206349206349,0.06349206349206349,0.06575963718820861,0.06575963718820861,0.06802721088435375,0.06802721088435375,0.07029478458049887,0.07029478458049887,0.07256235827664399,0.07256235827664399,0.07482993197278912,0.07482993197278912,0.07936507936507936,0.07936507936507936,0.08163265306122448,0.08163265306122448,0.08390022675736962,0.08390022675736962,0.08616780045351474,0.08616780045351474,0.08843537414965986,0.08843537414965986,0.09070294784580499,0.09070294784580499,0.09297052154195011,0.09297052154195011,0.09523809523809523,0.09523809523809523,0.09750566893424037,0.09750566893424037,0.09977324263038549,0.09977324263038549,0.10204081632653061,0.10204081632653061,0.10430839002267574,0.10430839002267574,0.10657596371882086,0.10657596371882086,0.10884353741496598,0.10884353741496598,0.1111111111111111,0.1111111111111111,0.11337868480725624,0.11337868480725624,0.11564625850340136,0.11564625850340136,0.11791383219954649,0.11791383219954649,0.12018140589569161,0.12018140589569161,0.12244897959183673,0.12244897959183673,0.12471655328798185,0.12471655328798185,0.12698412698412698,0.12698412698412698,0.1292517006802721,0.1292517006802721,0.13151927437641722,0.13151927437641722,0.13378684807256236,0.13378684807256236,0.1360544217687075,0.1360544217687075,0.1383219954648526,0.1383219954648526,0.14058956916099774,0.14058956916099774,0.14285714285714285,0.14285714285714285,0.14512471655328799,0.14512471655328799,0.1473922902494331,0.1473922902494331,0.14965986394557823,0.14965986394557823,0.15192743764172337,0.15192743764172337,0.15419501133786848,0.15419501133786848,0.1564625850340136,0.1564625850340136,0.15873015873015872,0.15873015873015872,0.16099773242630386,0.16099773242630386,0.16326530612244897,0.16326530612244897,0.16780045351473924,0.16780045351473924,0.1746031746031746,0.1746031746031746,0.17687074829931973,0.17687074829931973,0.17913832199546487,0.17913832199546487,0.18140589569160998,0.18140589569160998,0.1836734693877551,0.1836734693877551,0.18594104308390022,0.18594104308390022,0.19047619047619047,0.19047619047619047,0.19501133786848074,0.19501133786848074,0.19727891156462585,0.19727891156462585,0.19954648526077098,0.19954648526077098,0.2018140589569161,0.2018140589569161,0.20408163265306123,0.2040816 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ff8a0655-5c93-47f3-b69c-5636ddbdd926" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff8a0655-5c93-47f3-b69c-5636ddbdd926")) {                    Plotly.newPlot(                        "ff8a0655-5c93-47f3-b69c-5636ddbdd926",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"texttemplate":"%{z}","x":["Predicted 0","Predicted 1"],"y":["Actual 0","Actual 1"],"z":[[359,82],[215,1169]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...
# LogisticRegression Mean ROC-AUC: 0.9003
# Optimal Threshold: 0.4522
#
#
# ============================================================
# Best Hyperparameters
# ============================================================
#
# LogisticRegression:
#   C                    = 0.001071
#   max_iter             = 2654
#   class_weight         = None
#   tol                  = 0.001672
#   fit_intercept        = False
#   warm_start           = False
#   solver               = sag
#   penalty              = l2
# ============================================================
#
# Generating predictions with LogisticRegression
#
# Calculating Optimal Threshold from ROC Curve...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="049c2467-610b-467a-adcb-b37812f61ba3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("049c2467-610b-467a-adcb-b37812f61ba3")) {                    Plotly.newPlot(                        "049c2467-610b-467a-adcb-b37812f61ba3",                        [{"mode":"lines","name":"ROC Curve (AUC = 0.90)","x":[0.0,0.0,0.0,0.001851851851851852,0.001851851851851852,0.003703703703703704,0.003703703703703704,0.005555555555555556,0.005555555555555556,0.007407407407407408,0.007407407407407408,0.009259259259259259,0.009259259259259259,0.011111111111111112,0.011111111111111112,0.012962962962962963,0.012962962962962963,0.014814814814814815,0.014814814814814815,0.016666666666666666,0.016666666666666666,0.018518518518518517,0.018518518518518517,0.020370370370370372,0.020370370370370372,0.022222222222222223,0.022222222222222223,0.024074074074074074,0.024074074074074074,0.025925925925925925,0.025925925925925925,0.027777777777777776,0.027777777777777776,0.02962962962962963,0.02962962962962963,0.03148148148148148,0.03148148148148148,0.03333333333333333,0.03333333333333333,0.03518518518518519,0.03518518518518519,0.037037037037037035,0.037037037037037035,0.03888888888888889,0.03888888888888889,0.040740740740740744,0.040740740740740744,0.04259259259259259,0.04259259259259259,0.044444444444444446,0.044444444444444446,0.046296296296296294,0.046296296296296294,0.04814814814814815,0.04814814814814815,0.05,0.05,0.05185185185185185,0.05185185185185185,0.053703703703703705,0.053703703703703705,0.05555555555555555,0.05555555555555555,0.05740740740740741,0.05740740740740741,0.05925925925925926,0.05925925925925926,0.06111111111111111,0.06111111111111111,0.06296296296296296,0.06296296296296296,0.06666666666666667,0.06666666666666667,0.06851851851851852,0.06851851851851852,0.07037037037037037,0.07037037037037037,0.07222222222222222,0.07222222222222222,0.07592592592592592,0.07592592592592592,0.07777777777777778,0.07777777777777778,0.07962962962962963,0.07962962962962963,0.08148148148148149,0.08148148148148149,0.08333333333333333,0.08333333333333333,0.08518518518518518,0.08518518518518518,0.08703703703703704,0.08703703703703704,0.08888888888888889,0.08888888888888889,0.09074074074074075,0.09074074074074075,0.09259259259259259,0.09259259259259259,0.09444444444444444,0.09444444444444444,0.0962962962962963,0.0962962962962963,0.09814814814814815,0.09814814814814815,0.1,0.1,0.10185185185185185,0.10185185185185185,0.1037037037037037,0.1037037037037037,0.10555555555555556,0.10555555555555556,0.10740740740740741,0.10740740740740741,0.10925925925925926,0.10925925925925926,0.11296296296296296,0.11296296296296296,0.11481481481481481,0.11481481481481481,0.11851851851851852,0.11851851851851852,0.12037037037037036,0.12037037037037036,0.12222222222222222,0.12222222222222222,0.12407407407407407,0.12407407407407407,0.1259259259259259,0.1259259259259259,0.12777777777777777,0.12777777777777777,0.12962962962962962,0.12962962962962962,0.13148148148148148,0.13148148148148148,0.13333333333333333,0.13333333333333333,0.13518518518518519,0.13518518518518519,0.13703703703703704,0.13703703703703704,0.1388888888888889,0.1388888888888889,0.14074074074074075,0.14074074074074075,0.1425925925925926,0.1425925925925926,0.14444444444444443,0.14444444444444443,0.14814814814814814,0.14814814814814814,0.15,0.15,0.15185185185185185,0.15185185185185185,0.15555555555555556,0.15555555555555556,0.1574074074074074,0.1574074074074074,0.15925925925925927,0.15925925925925927,0.16111111111111112,0.16111111111111112,0.16296296296296298,0.16296296296296298,0.1648148148148148,0.1648148148148148,0.16666666666666666,0.16666666666666666,0.1685185185185185,0.1685185185185185,0.17037037037037037,0.17037037037037037 ...
# Visualizing Logistic Regression Predictions with Optimal Threshold...
# Saved submission_LogisticRegression.csv
#
# Saved best model (LogisticRegression) as best_model.pkl

# %% [markdown]
#  🎉  Conclusion & Next Steps
# =================
# ### Key Results
# | Metric          | Score  |
# |-----------------|--------|
# | Validation AUC  | 0.90  |
# | Optimal Threshold | 0.45  |
# | Feature Count   | 65     |
#
# ### Future Improvements
# ```markdown
# - [ ] Try gradient boosting models (XGBoost/LightGBM)
# - [ ] Implement SMOTE for class imbalance
# - [ ] Create ensemble of multiple models
# ```
#
# ---
#
# **🌟 Final Submission Ready!**
# **Good Luck in the Competition!** 🏅

# %% [markdown]
# <a id="toc"></a>
#
# <a href="#toc" style="background-color: #00a4f9; color: #ffffff; padding: 7px 10px; text-decoration: none; border-radius: 50px;">Back to top</a>
#
# ---
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em; color:#00a4f9;">
#     <em>Appreciate your time exploring my work. If you enjoyed it, kindly consider upvoting or feel free to drop comment / feedback to help enhance the notebook. Happy Learning!</em>
# </p>
#
#
# <center><img src='https://mir-s3-cdn-cf.behance.net/project_modules/1400/dea3c9102507757.5f3adfd3a2781.gif'
#      height=100px width=300px /></center>

# %% [markdown]
# # Author ✍️: Maimunul Karim Jisan
#
# ### 🎓 Education
# **Graduated from:** East Delta University, Bangladesh
#
# ---
#
# ### 🌟 About Me
# I am an aspiring data scientist with a strong interest in machine learning and data analysis. My passion lies in exploring innovative solutions to complex problems, and I continually strive to enhance my skills in this dynamic field.
#
# ---
#
# ### 📫 Connect with Me
# - [LinkedIn Profile](https://www.linkedin.com/in/maimunul-karim-jisan-6371a7140/)
# - [GitHub Profile](https://github.com/maimunul)
#
# ---
